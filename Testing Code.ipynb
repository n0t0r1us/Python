# %%
#@title resources
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#@title numpy
import numpy as np
d = np.random.random((10,10))*100
#Phần tử mặc định tạo ra có kiểu float
#Chuyển sang kiểu số nguyên int
d = d.astype(np.int64)
print(d)
print('Kiểu dữ liệu: \n', d.dtype)
print('Số chiều: \n', d.ndim)
print('Kích thước: \n', d.shape)
# Out:
# [[ 7 81 13 81 72 38 22 97 30 41]
#  [71 94 47 44 82 25 27 26 39 63]
#  [68 55 73 81 94 98 94 93 50 56]
#  [67 68 73 23 61 64 85 45 64 81]
#  [47 93 65 17  1 42 33 37 35  0]
#  [50 88 34 69 88 47 64 62 23 12]
#  [53 95 72 55 74 30  7 27 20 92]
#  [32 67 39 12 46 64 51 90 99 18]
#  [49 54 97 99 82 84 56 69 80 76]
#  [31 38 43 31 64 50 22 20 36 26]]
# Kiểu dữ liệu:
#  int64
# Số chiều:
#  2
# Kích thước:
#  (10, 10)

# %%
#Đọc file dữ liệu từ Drive
diem_2a = np.loadtxt("/content/gdrive/MyDrive/Python/Resources/Diem_2A.txt", delimiter = ',')
#Tính và in điểm trung bình các môn của từng học sinh
DTB = diem_2a.mean(axis = 0)

for i in range(0, DTB.size):
  print("Học sinh #", i + 1, " có điểm trung bình là: ", DTB[i])

#In ra điểm trung bình cao nhất và thấp nhất
print("Điểm trung bình cao nhất là: ", DTB.max())
print("Điểm trung bình thấp nhất là: ", DTB.min())
# Out:
# Học sinh # 1  có điểm trung bình là:  4.8
# Học sinh # 2  có điểm trung bình là:  6.0
# Học sinh # 3  có điểm trung bình là:  4.4
# Học sinh # 4  có điểm trung bình là:  8.6
# Học sinh # 5  có điểm trung bình là:  5.6
# Học sinh # 6  có điểm trung bình là:  6.5
# Học sinh # 7  có điểm trung bình là:  5.3
# Học sinh # 8  có điểm trung bình là:  5.4
# Học sinh # 9  có điểm trung bình là:  5.9
# Học sinh # 10  có điểm trung bình là:  5.1
# Học sinh # 11  có điểm trung bình là:  6.5
# Học sinh # 12  có điểm trung bình là:  5.1
# Học sinh # 13  có điểm trung bình là:  5.3
# Học sinh # 14  có điểm trung bình là:  5.9
# Học sinh # 15  có điểm trung bình là:  6.0
# Học sinh # 16  có điểm trung bình là:  7.9
# Học sinh # 17  có điểm trung bình là:  3.9
# Học sinh # 18  có điểm trung bình là:  6.1
# Học sinh # 19  có điểm trung bình là:  6.3
# Học sinh # 20  có điểm trung bình là:  4.0
# Học sinh # 21  có điểm trung bình là:  3.9
# Học sinh # 22  có điểm trung bình là:  5.3
# ...

# %%
#@title pandas
#pandas
import pandas as pd
df_patient= pd.read_csv('/content/gdrive/MyDrive/Python/Resources/Data_Patient.csv')
#Đặt cột feature_1 làm cột chỉ số
df_patient.set_index("feature_1")
#Hiển thị thông tin tổng quan của tập dữ liệu
print("Dataframe's info:")
df_patient.info()
print("-" * 50)
#Hiển thị thông tin của 10 bệnh nhân đầu tiên và 5 bệnh nhân cuối cùng của tập dữ liệu
print("First 10 records: \n", df_patient.head(10))
print("Last 5 records: \n",df_patient.tail())
print("-" * 50)
#Đặt lại tên các cột dữ liệu trong dataframe
df_patient.columns = ["id", "Age", "Gender", "Type", "Blood_Pressure", "Cholesterol", "Heartbeat", "Thalassemia", "Result"]
#In ra dataframe đã qua chỉnh sửa
print("New dataframe: \n", df_patient)
# Out:
# Dataframe's info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         300 non-null    object
#  1   feature_1  300 non-null    int64
#  2   feature_2  300 non-null    object
#  3   feature_3  295 non-null    object
#  4   feature_4  300 non-null    int64
#  5   feature_5  300 non-null    int64
#  6   feature_6  300 non-null    int64
#  7   feature_7  293 non-null    float64
#  8   feature_8  300 non-null    int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 21.2+ KB
# --------------------------------------------------
# First 10 records:
#             id  feature_1 feature_2  ... feature_6  feature_7  feature_8
# 0  Patient_01         63      Male  ...       150        6.0          0
# 1  Patient_02         67      Male  ...       108        3.0          1
# ...

# %%
#@title matplotlib
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/MyDrive/Python/Resources/Data_Temp.csv')
data.drop('time', axis=1, inplace= True)
data_max= data.max()
data_min= data.min()
data_mean= data.mean()
thanhphobuon = ['Hà Nội', 'Vinh', 'Đà Nẵng', 'Nha Trang', 'Hồ Chí Minh', 'Cà Mau']
fig,ax = plt.subplots(figsize=(10,5))   
ax.plot(data_max , color ='purple',  marker='*',  linestyle='-',  linewidth=2, markersize=9, label="ToC - Max")
ax.legend()
ax.grid(True)
ax.set_ylabel('Nhiệt độ')
ax.set_title('BIỂU ĐỒ BIỂU DIỄN NHIỆT ĐỘ MAX 6 THÀNH PHỐ')
plt.show()

# %%
#@title random
import random
print(random.choice(("you are the loser","you are the winner")))

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from datetime import datetime
import math
# Importing the most popular regression libraries.
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from xgboost import XGBRegressor

# %%
df = pd.read_csv("/content/drive/MyDrive/Python/Resources/weight-height-custom (1).csv")

# %%
plt.plot(df.Height, df.Weight, 'ro')
plt.xlabel("Chiều cao (cm)")
plt.ylabel("Cân nặng (Kg)")
plt.show()

# %%
X = df.loc[:,["Height"]].values
Y = df.Weight.values
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X
# Out:
# array([[147],
#        [150],
#        [153],
#        [155],
#        [168],
#        [170],
#        [173],
#        [175],
#        [178],
#        [180],
#        [183],
#        [165],
#        [163],
#        [160],
#        [158],
#        [169],
#        [172],
#        [170],
#        [176],
#        [180]])

# %%
Y
# Out:
# array([49, 50, 51, 51, 60, 62, 68, 65, 66, 71, 68, 59, 58, 56, 54, 62, 63,
#        62, 62, 69])

# %%
mse = mean_squared_error(model.predict(X), Y)
print("Tổng bình phương sai số trên tập mẫu : ", mse)
print("Hệ số hồi quy : ", model.coef_)
print("Sai số : ", model.intercept_)
print(model.coef_, model.intercept_ )
# Out:
# Tổng bình phương sai số trên tập mẫu :  2.546685519029107
# Hệ số hồi quy :  [0.61529398]
# Sai số :  -42.607917992223435
# [0.61529398] -42.607917992223435

# %%
plt.scatter(X, Y, c="b")
plt.plot(X, model.predict(X))
plt.show()

# %%
while(True):
  x = float(input("Nhập chiều cao (nhập 0 để dừng) : "))
  if x<=0:
    break
  print("Người cao ", x, "cm, dự báo cân nặng", model.predict([[x]]))
# Out:
# Nhập chiều cao (nhập 0 để dừng) : 0

# %% [markdown]
# prediction

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from datetime import datetime
import math
# Importing the most popular regression libraries.
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from xgboost import XGBRegressor
df = pd.read_csv("/content/drive/MyDrive/Python/Resources/weight-height-custom (1).csv")
plt.plot(df.Height, df.Weight, 'ro')
plt.xlabel("Chiều cao (cm)")
plt.ylabel("Cân nặng (Kg)")
plt.show()
X = df.loc[:,["Height"]].values
Y = df.Weight.values
model = LinearRegression()
model.fit(X,Y)
X
Y
mse = mean_squared_error(model.predict(X), Y)
print("Tổng bình phương sai số trên tập mẫu : ", mse)
print("Hệ số hồi quy : ", model.coef_)
print("Sai số : ", model.intercept_)
print(model.coef_, model.intercept_ )
plt.scatter(X, Y, c="b")
plt.plot(X, model.predict(X))
plt.show()
while(True):
  x = float(input("Nhập chiều cao (nhập 0 để dừng) : "))
  if x<=0:
    break
  print("Người cao ", x, "cm, dự báo cân nặng", model.predict([[x]]))
# Out:
# Tổng bình phương sai số trên tập mẫu :  2.546685519029107
# Hệ số hồi quy :  [0.61529398]
# Sai số :  -42.607917992223435
# [0.61529398] -42.607917992223435
# Nhập chiều cao (nhập 0 để dừng) : -1

# %%
#@title donut
import os
from math import sin, cos

def main():
    a=0
    b=0

    # for clearing console (windows and unix systems)
    clear = "cls"
    if os.name == "posix":
        clear = "clear"

    os.system(clear)
    while True:
        z = [0 for _ in range(7040)]
        screen = [' ' for _ in range(1760)]

        j=0
        while j<6.28:
            j+=0.07
            i=0
            while i<6.28:
                i+=0.02

                sinA=sin(a)
                cosA=cos(a)
                cosB=cos(b)
                sinB=sin(b)

                sini=sin(i)
                cosi=cos(i)
                cosj=cos(j)
                sinj=sin(j)

                cosj2=cosj+2
                mess=1/(sini*cosj2*sinA+sinj*cosA+5)
                t=sini*cosj2*cosA-sinj* sinA

                # 40 is the left screen shift
                x = int(40+30*mess*(cosi*cosj2*cosB-t*sinB))
                # 12 is the down screen shift
                y = int(12+15*mess*(cosi*cosj2*sinB +t*cosB))
                # all are casted to int, ie floored
                o = int(x+80*y)
                N = int(8*((sinj*sinA-sini*cosj*cosA)*cosB-sini*cosj*sinA-sinj*cosA-cosi *cosj*sinB))

                if 0<y<22 and 0<x<80 and z[o] < mess:
                    z[o]=mess
                    screen[o]=".,-~:;=!*#$@"[N if N>0 else 0]

        # prints
        os.system(clear)
        for index, char in enumerate(screen):
            if index % 80 == 0:
                print()
            else:
                print(char, end='')

        # increments
        a+=0.04
        b+=0.02

if __name__ == "__main__":
    main()

# %%
#include<iostream>
using namespace std;
int main()
{
#ifndef ONLINE_JUDGE
   freopen ("input.txt", "r", stdin);
   freopen ("output.txt", "w", stdout);
#endif
   int a, b;
   cin>>a>>b;
   cout<<a+b;
   return 0;
}
# Out:
#   File "<ipython-input-1-802329a86b14>", line 2
#     using namespace std;
#                   ^
# SyntaxError: invalid syntax
